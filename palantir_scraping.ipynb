# %%
import os
from openai import OpenAI
from bs4 import BeautifulSoup
import requests

# %%
api_key = os.getenv('OPENAI_API_KEY')

# %%
openai= OpenAI()

# %%
for i in range(5):
url = "https://www.palantir.com/docs/foundry/building-pipelines/overview/" 
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
# print(soup.prettify())
next_page = soup.find_all("a", class_="ptcom-design__neighbours-link__q1mqkq")[1]['href']
next_url = "https://www.palantir.com" + next_page
print(next_url)
response = requests.get(next_url)

# next_page = soup.find("a", class_="ptcom-design__neighbours-link__q1mqkq", title="NEXT")

print(next_page)
# print(next_page['href'])
next_page = soup.find("a", title=True)


# next_page = soup.find("span", title="PREVIOUS")
print(next_page)
# Out:
# https://www.palantir.com/docs/foundry/building-pipelines/pipeline-types/
# /docs/foundry/building-pipelines/pipeline-types/
# None

# %%
url = "https://www.palantir.com/docs/foundry/building-pipelines/overview/" 
while True:
    print(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    next_page = soup.find_all("a", class_="ptcom-design__neighbours-link__q1mqkq")[1]['href']
    url = "https://www.palantir.com" + next_page
    if not next_page:
        break
# Out:
# https://www.palantir.com/docs/foundry/building-pipelines/overview/
# https://www.palantir.com/docs/foundry/building-pipelines/pipeline-types/
# https://www.palantir.com/docs/foundry/building-pipelines/supported-languages/
# https://www.palantir.com/docs/foundry/building-pipelines/considerations-pb-cr/
# https://www.palantir.com/docs/foundry/building-pipelines/create-batch-pipeline-pb/
# https://www.palantir.com/docs/foundry/building-pipelines/create-batch-pipeline-pb-media-set/
# https://www.palantir.com/docs/foundry/building-pipelines/create-batch-pipeline-cr/
# https://www.palantir.com/docs/foundry/building-pipelines/create-batch-pipeline-cr-media-sets/
# https://www.palantir.com/docs/foundry/building-pipelines/create-incremental-pipeline-pb/
# https://www.palantir.com/docs/foundry/building-pipelines/create-stream-pipeline-pb/
# https://www.palantir.com/docs/foundry/building-pipelines/incremental-overview/
# https://www.palantir.com/docs/foundry/building-pipelines/create-incremental-syncs/
# https://www.palantir.com/docs/foundry/building-pipelines/maintaining-incremental-performance/
# https://www.palantir.com/docs/foundry/building-pipelines/streaming-overview/
# https://www.palantir.com/docs/foundry/building-pipelines/stream-vs-batch/
# https://www.palantir.com/docs/foundry/building-pipelines/streaming-performance-considerations/
# https://www.palantir.com/docs/foundry/building-pipelines/streaming-compute-usage/
# https://www.palantir.com/docs/foundry/building-pipelines/streaming-keys/
# https://www.palantir.com/docs/foundry/building-pipelines/streaming-stateful-transforms/
# https://www.palantir.com/docs/foundry/building-pipelines/scheduling-overview/
# https://www.palantir.com/docs/foundry/building-pipelines/create-schedule/
# https://www.palantir.com/docs/foundry/building-pipelines/view-modify-schedules/
# https://www.palantir.com/docs/foundry/building-pipelines/find-manage-schedules/
# https://www.palantir.com/docs/foundry/building-pipelines/common-schedules/
# https://www.palantir.com/docs/foundry/building-pipelines/triggers-reference/
# https://www.palantir.com/docs/foundry/building-pipelines/schedule-troubleshooting/
# https://www.palantir.com/docs/foundry/building-pipelines/marketplace-schedules/
# https://www.palantir.com/docs/foundry/building-pipelines/logic-flows-overview/
# https://www.palantir.com/docs/foundry/building-pipelines/create-a-connected-flow/
# https://www.palantir.com/docs/foundry/building-pipelines/compass-file-lister/
# https://www.palantir.com/docs/foundry/building-pipelines/recommended-project-structure/
# https://www.palantir.com/docs/foundry/building-pipelines/development-best-practices/
# https://www.palantir.com/docs/foundry/building-pipelines/branching-release-process/
# https://www.palantir.com/docs/foundry/building-pipelines/scheduling-best-practices/
# https://www.palantir.com/docs/foundry/building-pipelines/building-production-pipeline/
# https://www.palantir.com/docs/foundry/building-pipelines/unstructured-overview/
# https://www.palantir.com/docs/foundry/building-pipelines/infer-schema/
# https://www.palantir.com/docs/foundry/building-pipelines/security-overview/
# https://www.palantir.com/docs/foundry/building-pipelines/remove-markings/
# https://www.palantir.com/docs/foundry/building-pipelines/remove-inherited-markings/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/overview/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/debug-job/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/debug-pipeline/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/debug-stream/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/troubleshoot-ooms/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/troubleshoot-schedules/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/spark-concepts/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/understand-spark-details/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/spark-ui/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/understand-compute/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/native-acceleration/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/apply-spark-profiles/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/spark-profiles-reference/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/hive-style-partitioning/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/projections-overview/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/projections-setup/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/projections-advanced/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/projections-vs-hive-style-partitioning/
# https://www.palantir.com/docs/foundry/optimizing-pipelines/usage-optimization/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/overview/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/stability-recommendations/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/recommended-health-checks/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/define-data-expectations/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/support-processes/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/monitoring-views-intro/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/monitoring-rules-reference/
# https://www.palantir.com/docs/foundry/maintaining-pipelines/sending-alerts-to-external-systems/
# https://www.palantir.com/docs/foundry/pipeline-builder/overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/core-concepts/
# https://www.palantir.com/docs/foundry/pipeline-builder/navigation/
# https://www.palantir.com/docs/foundry/pipeline-builder/pipeline-builder-aip/
# https://www.palantir.com/docs/foundry/pipeline-builder/functions-index/
# https://www.palantir.com/docs/foundry/pipeline-builder/datasets-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/datasets-add/
# https://www.palantir.com/docs/foundry/pipeline-builder/datasets-generated/
# https://www.palantir.com/docs/foundry/pipeline-builder/datasets-sources/
# https://www.palantir.com/docs/foundry/pipeline-builder/datasets-computation-modes-for-batch/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-transform-data/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-join-data/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-union-data/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-transform-media/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-geospatial/
# https://www.palantir.com/docs/foundry/pipeline-builder/unique-id-creation/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-streaming-joins/
# https://www.palantir.com/docs/foundry/pipeline-builder/pipeline-builder-llm/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-split/
# https://www.palantir.com/docs/foundry/pipeline-builder/transforms-pattern-mining/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-add-dataset-output/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-add-media-set-output/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-add-virtual-table-output/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-add-ontology-output/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-add-geotemporal-series-output/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-preview-pipeline/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-deliver-pipeline/
# https://www.palantir.com/docs/foundry/pipeline-builder/outputs-remove-markings/
# https://www.palantir.com/docs/foundry/pipeline-builder/breaking-changes/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-input-sampling/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-parameter-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-build-settings/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-create-custom-functions/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-show-hide-nodes/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-file-tree/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-color-groups/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-charts/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-text-nodes/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-checkpoints/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-job-groups/
# https://www.palantir.com/docs/foundry/pipeline-builder/export-pipeline/
# https://www.palantir.com/docs/foundry/pipeline-builder/management-find-and-replace/
# https://www.palantir.com/docs/foundry/pipeline-builder/branches-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/branches-create-a-branch/
# https://www.palantir.com/docs/foundry/pipeline-builder/branches-propose-a-change/
# https://www.palantir.com/docs/foundry/pipeline-builder/branches-approve-a-change/
# https://www.palantir.com/docs/foundry/pipeline-builder/branches-protected-branches/
# https://www.palantir.com/docs/foundry/pipeline-builder/branches-fallback-branches/
# https://www.palantir.com/docs/foundry/pipeline-builder/schedules-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/schedules-create-schedule/
# https://www.palantir.com/docs/foundry/pipeline-builder/schedules-scheduler-aip/
# https://www.palantir.com/docs/foundry/pipeline-builder/dataexpectations-overview/
# https://www.palantir.com/docs/foundry/pipeline-builder/dataexpectations-configure-health-check/
# https://www.palantir.com/docs/foundry/pipeline-builder/dataexpectations-unit-tests/
# https://www.palantir.com/docs/foundry/pipeline-builder/marketplace-pipeline-builder/
# https://www.palantir.com/docs/foundry/pb-functions-expression/absV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/addV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/addOrUpdateMapEntryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/addOrUpdateStructFieldV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/dateAddV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/allArrayElementsSatisfyV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/allOfV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/andV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/anyArrayElementSatisfyV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/anyOfV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/approxMedianV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/approximatePercentileV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arccosV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arcsinV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arctanV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arctan2V1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/areaV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayAddV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraysCartesianProductV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayConcatV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayContainsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayContainsNullV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayDifferenceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayDistinctV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayElementV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isArrayUniqueV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayFlattenV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayIntersectV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayMaxV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayMinV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayPositionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayRemoveV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayRepeatV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayReverseV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraySortV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraySortByKeyV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayUnionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraysHaveIntersectionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraysZipV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/base64DecodeToStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/base64DecodeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/base64EncodeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/bitShiftLeftV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/bitShiftRightV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/h3BufferV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/inverseHaversineV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/haversineV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/caseV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/castV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/ceilV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/changeTimestampTimeZoneV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/translateStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/chunkStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cipherDecryptV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cipherEncryptV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cipherHashV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cleanStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/collectArrayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/collectDistinctArrayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/compactH3SetV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/concatStringsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/constructDelegatedMediaGidV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/dmsToGeoPointV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geoPointToGeohashV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geoPointToMgrsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geoPointToGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/mgrsToGeoPointV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/stringToDateV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/stringToTimestampV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/convertBaseV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/convertAngleV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/convertDistanceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/convertTimeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/convertWeightV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/jsonStringV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/ontologyGeopointToGeopointV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/UnhexV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/UnhexToStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/GeocentricToGeodesicV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/convertLegacyOffsetDateTimeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/linestringToPolygonV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampFromUtcV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampToUtcV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createOntologyGeopointV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/HexV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/octalV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cosineV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/covarianceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/constructGeoPointV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createGeoPointFromCoordinateSystemV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createEmptyArrayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createArrayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createGeoEllipseGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createGeodesicLineStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createGeoLineStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/mapFromArraysV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createNullValueV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createGeoRangeFanGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createGeometryFromOrderedGeoPointRowsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createStructV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/createQualifiedTimeSeriesIdV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/currentDateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/currentTimestampV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/dateSequenceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/decodeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geobufToGeometryExpressionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/denseRankV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/distinctCountV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/divideV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryToGeobufExpressionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/endsWithV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/epochMillisToDateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/epochMillisToTimestampV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/epochSecondsToDateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/epochSecondsToTimestampV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/equalsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/explodeArrayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/explodeArrayWithPositionV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/explodeMapV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/exponentialV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/regexExtractAllV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/datePartV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getDocumentMetadataV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getImageryMetadataV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/pdfLayoutAwareContentExtractionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/imageLayoutAwareContentExtractionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/extractMapKeysV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/extractMapValuesV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/extractOffsetFromLegacyOffsetDateTimeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/pdfTableOfContentsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/pdfTextExtractionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/pdfOcrV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/imageOcrV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampPartV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/filterArrayElementV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryFilterV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/firstV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/firstNonNullV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/floorV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/dateToStringV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/formatNumberV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/formatStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampToStringV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryIntersectsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometry3dAffineTransformationV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryArrayUnionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryArrayLineDissolveV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryBufferV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryCentroidV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryContainsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryDifferenceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryExplodeToArrayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryIntersectionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryLengthV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryRotate2dV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometrySetZCoordinateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryShortestDistanceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryStandardizeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometrySymmetricDifferenceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryTranslateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryUnionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/h3IndexExpressionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/polygonToH3V1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getMimeTypeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getPdfPageDimensionsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/xzCurveEncodeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getBearingV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryEnvelopeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/latLonBoundingBoxV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/h3NeighborsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getStructFieldV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/geometryConvexHullV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/greaterThanV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/greaterThanOrEqualsV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/greatestV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/groupedGeometryEnvelopeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/groupedGeometryUnionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/groupedLatLonBoundingBoxV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/gzipDecompressV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/h3CellToChildrenV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/h3CellToParentV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/h3ToGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sha256V1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/interpolateGeoPointAlongLinestringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isNaNV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isEmptyStructV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isInV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isNotNullV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isNullV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidGeoJsonV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidGeohashV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidH3IndexV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidMgrsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidMimeTypeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidOntologyGeopointV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidDelegatedMediaGidV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidMediaReferenceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidRidV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/isValidUuidV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arrayJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lagV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lastV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lastDayV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/leadV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/leastV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/leftStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/leftPadV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lengthV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lessThanV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lessThanOrEqualsV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/levenshteinDistanceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/linearRegressionGradientV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/logV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/logNV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/logicalTypeCastV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/lowercaseV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/mapValuesV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/maxV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/maxByV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/meanV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/minV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/minByV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/modeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/moduloV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/multiplyV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/naturalRandomV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/negateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/normalRandomV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/notV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/getNthChainFromPolygonV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/linestringPointNV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/nullifyEmptyStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/orV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseGeoJsonAsGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseJsonAsSchemaV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseKmlAsGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseXmlAsSchemaV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cbacStringToGroupNamesV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseDurationV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parsePhoneNumberV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseWellKnownBinaryAsGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/parseWellKnownTextAsGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/percentRankV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/perimeterV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/pivotExpressionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/positiveModuloV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/powerOfV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/normalizeGeometryV4/
# https://www.palantir.com/docs/foundry/pb-functions-expression/productV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/rankV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/reduceArrayElementsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/regexExtractV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/regexFindV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/regexIndexV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/regexMatchV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/regexReplaceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/removeMapEntryByKeyV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/renameStructFieldV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/rightStringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/rightPadV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/roundV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/rowCountV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/rowNumberV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sampleCovarianceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sampleVarianceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/secantV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sentenceCaseV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sequenceV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/similarityScoreV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/simplifyGeometryV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sineV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/skipBytesV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraySliceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/soundexV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/splitStringV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sqrtV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/standardDeviationV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/startsWithV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/stringAfterDelimiterV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/stringBeforeDelimiterV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/stringContainsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/substringV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/subtractManyV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/subtractV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampDiffV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/dateSubV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/sumV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/arraySumV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/tangentV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/textSegmentationV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/textToEmbeddingsV2/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampAddV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampSequenceV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampSubtractV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampToEpochMillisV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampToEpochSecondsV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/titleCaseV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/cpuJsonAudioTranscriptionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/gpuJsonAudioTranscriptionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/audioTranscriptionV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/transformArrayElementV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/transformMapKeysV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/transformMapValuesV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/trimV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/dateTruncateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/timestampTruncateV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/uncompactH3SetV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/unicodeNormalizeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/uniformRandomV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/uuidV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/uppercaseV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/urlDecodeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/urlEncodeV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/useLlmV3/
# https://www.palantir.com/docs/foundry/pb-functions-expression/valueFromMapV1/
# https://www.palantir.com/docs/foundry/pb-functions-expression/varianceV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/aggregateV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/aggregateOnConditionV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/aggregateOverWindowV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexAntiJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/applyExpressionV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/projectV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/projectOnConditionV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/arrayToColumnsV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/assignTimestampsAndWatermarksV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/coalesceV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/computeExpressionIfAbsentV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/loadMediaSetReferencesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexCrossJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/dateDistributionV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/dropV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/dropDuplicatesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/emptyFileV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/emptyMediaSetFileV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/emptyTableV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/extractFileMetadataAsRowsV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/getManyStructFieldsV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseCsvV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseGeoJsonV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseJsonV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/extractEmailDataAsRowsV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseTextFileV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseExcelV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/xmlTagExtractV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseShapefileV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/filterV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/filterFilesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/firstUnionByNameV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/flattenStructV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/fpGrowthV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoDistanceInnerJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoDistanceLeftJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoIntersectionInnerJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoIntersectionLeftJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoPointToPoint3dDistanceInnerJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoIntersectionJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoKnnInnerJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/geoKnnLeftJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/loadMediaReferencesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/heartbeatDetectionV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexInnerJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/joinV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/kmeansV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexKnnJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/keepDuplicatesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/keyByV3/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexLeftJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/leftLookupJoinV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/manuallyEnteredTableV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/mappingJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/narrowUnionByNameV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/normalizeColumnNamesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/numericDistributionV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/frontendOuterCachingJoinV3/
# https://www.palantir.com/docs/foundry/pb-functions-transform/outerCachingJoinV3/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexOuterJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/parseKmlFilesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/pivotV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/windowedProjectV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/renameColumnsV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/repartitionV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/rollUpV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/rowSizeV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/selectV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/complexSemiJoinV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/sortV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/splitOnConditionV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/textBlockV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/timeBoundedDropDuplicatesV3/
# https://www.palantir.com/docs/foundry/pb-functions-transform/timeBoundedDropOutOfOrderTransformV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/timeBoundedEventTimeSortV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/topRowV2/
# https://www.palantir.com/docs/foundry/pb-functions-transform/unionByNameV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/unionFilesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/unpivotV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/unzipFilesV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/wideUnionByNameV1/
# https://www.palantir.com/docs/foundry/pb-functions-transform/windowV1/
# https://www.palantir.com/docs/foundry/code-repositories/overview/
# https://www.palantir.com/docs/foundry/code-repositories/navigation/
# https://www.palantir.com/docs/foundry/code-repositories/configure-repositories-in-control-panel/
# https://www.palantir.com/docs/foundry/code-repositories/faq/
# https://www.palantir.com/docs/foundry/code-repositories/create-transforms/
# https://www.palantir.com/docs/foundry/code-repositories/preview-transforms/
# https://www.palantir.com/docs/foundry/code-repositories/debug-transforms/
# https://www.palantir.com/docs/foundry/code-repositories/use-project-references/
# https://www.palantir.com/docs/foundry/code-repositories/analyze-impact/
# https://www.palantir.com/docs/foundry/code-repositories/unit-tests/
# https://www.palantir.com/docs/foundry/code-repositories/module-pinning/
# https://www.palantir.com/docs/foundry/code-repositories/libraries/
# https://www.palantir.com/docs/foundry/code-repositories/readme/
# https://www.palantir.com/docs/foundry/code-repositories/aip-features/
# https://www.palantir.com/docs/foundry/code-repositories/marketplace-dataset-transformation/
# https://www.palantir.com/docs/foundry/code-repositories/artifact-repositories-overview/
# https://www.palantir.com/docs/foundry/code-repositories/artifact-repositories-nav/
# https://www.palantir.com/docs/foundry/code-repositories/create-artifact-repository/
# https://www.palantir.com/docs/foundry/code-repositories/delete-artifact-repository/
# https://www.palantir.com/docs/foundry/code-repositories/publish-artifact/
# https://www.palantir.com/docs/foundry/code-repositories/recall-artifact/
# https://www.palantir.com/docs/foundry/code-repositories/manage-permissions/
# https://www.palantir.com/docs/foundry/code-repositories/create-custom-checks/
# https://www.palantir.com/docs/foundry/code-repositories/prepare-datasets-download/
# https://www.palantir.com/docs/foundry/code-repositories/admin-overview/
# https://www.palantir.com/docs/foundry/code-repositories/branch-settings/
# https://www.palantir.com/docs/foundry/code-repositories/repository-settings/
# https://www.palantir.com/docs/foundry/code-repositories/repository-upgrades/
# https://www.palantir.com/docs/foundry/code-repositories/spark-profiles/
# https://www.palantir.com/docs/foundry/code-repositories/artifact-settings/
# https://www.palantir.com/docs/foundry/code-repositories/ontology-imports/
# https://www.palantir.com/docs/foundry/code-repositories/advanced-settings/
# https://www.palantir.com/docs/foundry/code-repositories/compute-usage/
# https://www.palantir.com/docs/foundry/data-lineage/overview/
# https://www.palantir.com/docs/foundry/data-lineage/navigation/
# https://www.palantir.com/docs/foundry/data-lineage/faq/
# https://www.palantir.com/docs/foundry/data-lineage/explore-lineage/
# https://www.palantir.com/docs/foundry/data-lineage/explore-artifacts/
# https://www.palantir.com/docs/foundry/data-lineage/save-share-graph/
# https://www.palantir.com/docs/foundry/data-lineage/node-coloring/
# https://www.palantir.com/docs/foundry/data-lineage/elements-reference/
# https://www.palantir.com/docs/foundry/data-lineage/dataset-preview-logic/
# https://www.palantir.com/docs/foundry/data-lineage/build-timeline/
# https://www.palantir.com/docs/foundry/data-lineage/stale-datasets/
# https://www.palantir.com/docs/foundry/data-lineage/find-column/
# https://www.palantir.com/docs/foundry/data-lineage/build-datasets/
# https://www.palantir.com/docs/foundry/data-lineage/manage-schedules/
# https://www.palantir.com/docs/foundry/data-lineage/check-permissions/
# https://www.palantir.com/docs/foundry/data-lineage/see-impact-marking-changes/
# https://www.palantir.com/docs/foundry/data-health/overview/
# https://www.palantir.com/docs/foundry/data-health/builds-checks-faq/
# https://www.palantir.com/docs/foundry/data-health/check-types/
# https://www.palantir.com/docs/foundry/data-health/check-evaluation/
# https://www.palantir.com/docs/foundry/data-health/watching-checks/
# https://www.palantir.com/docs/foundry/data-health/notifications/
# https://www.palantir.com/docs/foundry/data-health/checks-reference/
# https://www.palantir.com/docs/foundry/data-health/check-groups-overview/
# https://www.palantir.com/docs/foundry/data-health/create-watch-check-group/
# https://www.palantir.com/docs/foundry/data-health/view-check-group/
# https://www.palantir.com/docs/foundry/data-health/marketplace-data-health/
# https://www.palantir.com/docs/foundry/dataset-preview/overview/
# https://www.palantir.com/docs/foundry/dataset-preview/csv-parsing/
# https://www.palantir.com/docs/foundry/dataset-preview/sql-preview/
# https://www.palantir.com/docs/foundry/dataset-preview/dataset-preview-faq/
# https://www.palantir.com/docs/foundry/linter/overview/
# https://www.palantir.com/docs/foundry/linter/modes/
# https://www.palantir.com/docs/foundry/linter/recommendations/
# https://www.palantir.com/docs/foundry/linter/rules/
# https://www.palantir.com/docs/foundry/linter/sweep-schedules/
# https://www.palantir.com/docs/foundry/linter/impact-tracking/
# https://www.palantir.com/docs/foundry/peer-manager/overview/
# https://www.palantir.com/docs/foundry/peer-manager/core-concepts/
# https://www.palantir.com/docs/foundry/peer-manager/faq/
# https://www.palantir.com/docs/foundry/preparation/overview/
# https://www.palantir.com/docs/foundry/preparation/getting-started/
# https://www.palantir.com/docs/foundry/preparation/preparation-tutorial/
# https://www.palantir.com/docs/foundry/preparation/project-references/
# https://www.palantir.com/docs/foundry/preparation/basic-examples/
# https://www.palantir.com/docs/foundry/preparation/advanced-examples/
# https://www.palantir.com/docs/foundry/preparation/faq/
# https://www.palantir.com/docs/foundry/recipes/overview/
# https://www.palantir.com/docs/foundry/recipes/core-concepts/
# https://www.palantir.com/docs/foundry/recipes/create-a-recipe/
# https://www.palantir.com/docs/foundry/recipes/view-recipes/
# https://www.palantir.com/docs/foundry/recipes/configure-notifications/
# https://www.palantir.com/docs/foundry/recipes/edit-a-recipe/
# https://www.palantir.com/docs/foundry/transforms-python/overview/
# https://www.palantir.com/docs/foundry/transforms-python/getting-started/
# https://www.palantir.com/docs/foundry/transforms-python/python-versions/
# https://www.palantir.com/docs/foundry/transforms-python/transforms-pipelines/
# ...
# https://www.palantir.com/docs/foundry/transforms-python/create-historical-dataset/
# https://www.palantir.com/docs/foundry/transforms-python/incremental-media-sets/
# https://www.palantir.com/docs/foundry/transforms-python/environment-overview/
# https://www.palantir.com/docs/foundry/transforms-python/environment-creation-overview/
# https://www.palantir.com/docs/foundry/transforms-python/environment-troubleshooting/
# https://www.palantir.com/docs/foundry/transforms-python/use-python-libraries/
# https://www.palantir.com/docs/foundry/transforms-python/share-python-libraries/
# https://www.palantir.com/docs/foundry/transforms-python/local-development/
# https://www.palantir.com/docs/foundry/transforms-python/velox-overview/
# https://www.palantir.com/docs/foundry/transforms-python/lightweight-overview/
# https://www.palantir.com/docs/foundry/transforms-python/lightweight-api/
# https://www.palantir.com/docs/foundry/transforms-python/lightweight-examples/
# https://www.palantir.com/docs/foundry/transforms-python/tables-overview/
# https://www.palantir.com/docs/foundry/transforms-python/tables-bigquery/
# https://www.palantir.com/docs/foundry/transforms-python/tables-databricks/
# https://www.palantir.com/docs/foundry/transforms-python/tables-snowflake/
# https://www.palantir.com/docs/foundry/transforms-python/aip-orchestrators/
# https://www.palantir.com/docs/foundry/transforms-python/palantir-provided-models/
# https://www.palantir.com/docs/foundry/transforms-python/container-overview/
# https://www.palantir.com/docs/foundry/transforms-python/transforms-sidecar/
# https://www.palantir.com/docs/foundry/transforms-python/data-expectations-getting-started/
# https://www.palantir.com/docs/foundry/transforms-python/data-expectations-reference/
# https://www.palantir.com/docs/foundry/transforms-python/read-files-repository/
# https://www.palantir.com/docs/foundry/transforms-python/output-column-metadata/
# https://www.palantir.com/docs/foundry/transforms-python/transforms-python-api/
# https://www.palantir.com/docs/foundry/transforms-python/transforms-python-api-classes/
# https://www.palantir.com/docs/foundry/transforms-python/transforms-python-foundry-connectors/
# https://www.palantir.com/docs/foundry/transforms-python/media-sets/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-overview/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-coming-from-python/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-syntax-cheat-sheet/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-style-guide/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-columns/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-queries/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-udfs/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-filtering/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-dates/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-strings/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-math/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-joins/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-aggregation/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-window/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-logging/
# https://www.palantir.com/docs/foundry/transforms-python/pyspark-other/
# https://www.palantir.com/docs/foundry/transforms-java/overview/
# https://www.palantir.com/docs/foundry/transforms-java/getting-started/
# https://www.palantir.com/docs/foundry/transforms-java/transforms-pipelines/
# https://www.palantir.com/docs/foundry/transforms-java/transforms-examples/
# https://www.palantir.com/docs/foundry/transforms-java/unstructured-files/
# https://www.palantir.com/docs/foundry/transforms-java/unit-tests/
# https://www.palantir.com/docs/foundry/transforms-java/advanced-configuration/
# https://www.palantir.com/docs/foundry/transforms-java/incremental-transforms/
# https://www.palantir.com/docs/foundry/transforms-java/user-defined-functions/
# https://www.palantir.com/docs/foundry/transforms-java/share-code/
# https://www.palantir.com/docs/foundry/transforms-java/local-development/
# https://www.palantir.com/docs/foundry/transforms-java/spark-syntax/
# https://www.palantir.com/docs/foundry/transforms-sql/overview/
# https://www.palantir.com/docs/foundry/transforms-sql/spark-reference/
# https://www.palantir.com/docs/foundry/transforms-r/overview/
# https://www.palantir.com/docs/foundry/transforms-r/getting-started/
# https://www.palantir.com/docs/foundry/transforms-common/local-preview/
# https://www.palantir.com/docs/foundry/transforms-common/transforms-versions/
# https://www.palantir.com/docs/foundry/transforms-common/optimize-multi-output-transforms/
# https://www.palantir.com/docs/foundry/time-series/time-series-overview/
# https://www.palantir.com/docs/foundry/time-series/time-series-time-series-catalog/
# https://www.palantir.com/docs/foundry/time-series/time-series-concepts-glossary/
# https://www.palantir.com/docs/foundry/time-series/time-series-setup/
# https://www.palantir.com/docs/foundry/time-series/create-or-select-ts-ot/
# https://www.palantir.com/docs/foundry/time-series/time-series-properties/
# https://www.palantir.com/docs/foundry/time-series/time-series-syncs/
# https://www.palantir.com/docs/foundry/time-series/create-sensor-ot/
# https://www.palantir.com/docs/foundry/time-series/time-series-permissions/
# https://www.palantir.com/docs/foundry/time-series/interpolation-overview/
# https://www.palantir.com/docs/foundry/time-series/advanced-setup/
# https://www.palantir.com/docs/foundry/time-series/alerting-overview/
# https://www.palantir.com/docs/foundry/time-series/alerting-setup/
# https://www.palantir.com/docs/foundry/time-series/alerting-common-questions/
# https://www.palantir.com/docs/foundry/time-series/derived-series-overview/
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Projects\llm_project\venv\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[35], line 4
#       2 while True:
#       3     print(url)
# ----> 4     response = requests.get(url)
#       5     soup = BeautifulSoup(response.content, 'html.parser')
#       6     next_page = soup.find_all("a", class_="ptcom-design__neighbours-link__q1mqkq")[1]['href']
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Projects\llm_project\venv\Lib\site-packages\requests\adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
